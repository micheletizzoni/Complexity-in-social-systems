# %% [markdown]
# <center>
# <hr>
# <h1>Complessità nei sistemi sociali</h1>
# <h2>Laurea Magistrale in Fisica Dei Sistemi Complessi</h2>
# <h2>A.A. 2018/19</h2>
# <h3>Daniela Paolotti & Michele Tizzoni</h3>
# <h3>Notebook 5 - Basic network analysis with NetworkX, assortativity, resilience to attacks</h3>
# <hr>
# </center>

# %%
import networkx as nx
import seaborn as sns

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Connectivity and clustering of a graph
#
# We study the network of coauthorships of Astro-Ph, from the SNAP database.

# %%
filepath='./../network_data/ca-AstroPh.txt'

# %%
G=nx.Graph()

# %%
fh=open(filepath,'r')
for line in fh.readlines():
    s=line.strip().split()
    if s[0]!='#':
        origin=int(s[0])
        dest=int(s[1])
        G.add_edge(origin,dest)
fh.close()

# %%
print("The graph has", len(G), "nodes and",len(G.edges()),"edges")
# Out:
# The graph has 18772 nodes and 198110 edges

# %%
print("Is the graph simply connected?", nx.is_connected(G))
# Out:
# Is the graph simply connected? False

# %% [markdown]
# ### Show the components of the graph

# %%
print("The graph has", nx.number_connected_components(G),"connected components")
# Out:
# The graph has 290 connected components

# %%
for k in nx.connected_components(G):
    print(len(k))
# Out:
# 17903
# 2
# 3
# 4
# 8
# 2
# 2
# 4
# 3
# 5
# 3
# 3
# 2
# 2
# 5
# 5
# 2
# 7
# 2
# 3
# 10
# 3
# 4
# 4
# 4
# 2
# 2
# 3
# 6
# 4
# 2
# 4
# 2
# 3
# 2
# 2
# 5
# 4
# 6
# 2
# 2
# 5
# 3
# 2
# 2
# 2
# 2
# 4
# 3
# 2
# 4
# 2
# 3
# 3
# 2
# 3
# 3
# 2
# 3
# 3
# 5
# 3
# 2
# 3
# 5
# 3
# 2
# 3
# 2
# 2
# 3
# 2
# 3
# 4
# 3
# 3
# 3
# 3
# 2
# 5
# 2
# 4
# 2
# 4
# 10
# 2
# 3
# 3
# 3
# 4
# 3
# 2
# 3
# 2
# 2
# 3
# 5
# 2
# 3
# 2
# 3
# 2
# 3
# 2
# 3
# 9
# 2
# 3
# 4
# 3
# 4
# 3
# 3
# 5
# 5
# 2
# 3
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 3
# 4
# 2
# 2
# 2
# 2
# 2
# 3
# 3
# 2
# 3
# 2
# 2
# 4
# 2
# 2
# 4
# 4
# 3
# 3
# 2
# 2
# 3
# 3
# 3
# 2
# 3
# 2
# 2
# 2
# 2
# 4
# 3
# 2
# 12
# 2
# 3
# 8
# 3
# 2
# 2
# 7
# 4
# 3
# 3
# 2
# 2
# 2
# 2
# 3
# 2
# 3
# 2
# 2
# 3
# 2
# 2
# 3
# 2
# 4
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 3
# 3
# 2
# 2
# 2
# 4
# 2
# 3
# 2
# 3
# 2
# 4
# 2
# 4
# 2
# 4
# 4
# 2
# 5
# 2
# 2
# 2
# 3
# 2
# 4
# 2
# 2
# 3
# 3
# 3
# 3
# 8
# 2
# 3
# 2
# 2
# 3
# 2
# 2
# 2
# 2
# 4
# 1
# 3
# 2
# 2
# 2
# 2
# 3
# 2
# 2
# 3
# 2
# 2
# 2
# 2
# 3
# 2
# 2
# 5
# 2
# 4
# 2
# 6
# 18
# 3
# 2
# 3
# 3
# 2
# 2
# 3
# 4
# 2
# 2
# 4
# 3
# 3
# 4
# 7
# 5
# 2
# 3
# 3
# 2
# 2
# 4
# 2
# 4
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 3
# 2
# 2

# %% [markdown]
# ### Extract the largest Connected Component as a subgraph

# %%
nx.connected_component_subgraphs(G)
# Out:
# <generator object connected_component_subgraphs at 0x1a0f1da780>

# %%
graphs = list(nx.connected_component_subgraphs(G))

# %%
graphs
# Out:
# [<networkx.classes.graph.Graph at 0x1a0f1e3390>,
#  <networkx.classes.graph.Graph at 0x1a0f1e33c8>,
#  <networkx.classes.graph.Graph at 0x1a0f1e36a0>,
#  <networkx.classes.graph.Graph at 0x1a0f1e3358>,
#  <networkx.classes.graph.Graph at 0x1a0f1e3438>,
#  <networkx.classes.graph.Graph at 0x1a0f1e3470>,
#  <networkx.classes.graph.Graph at 0x1a0f1e34a8>,
#  <networkx.classes.graph.Graph at 0x1a0f1e34e0>,
#  <networkx.classes.graph.Graph at 0x1a0f1e3518>,
#  <networkx.classes.graph.Graph at 0x1a0f1e3400>,
#  <networkx.classes.graph.Graph at 0x1a0f1e3550>,
#  <networkx.classes.graph.Graph at 0x1a0f1e3588>,
#  <networkx.classes.graph.Graph at 0x1a0f1e35c0>,
#  <networkx.classes.graph.Graph at 0x1a0f1e3630>,
#  <networkx.classes.graph.Graph at 0x1a0f1e3668>,
#  <networkx.classes.graph.Graph at 0x1a0f1e35f8>,
#  <networkx.classes.graph.Graph at 0x1a0f1e3780>,
#  <networkx.classes.graph.Graph at 0x1a0f1e3898>,
#  <networkx.classes.graph.Graph at 0x1a0f1e36d8>,
#  <networkx.classes.graph.Graph at 0x1a0f1e3748>,
#  <networkx.classes.graph.Graph at 0x1a0f1e3710>,
#  <networkx.classes.graph.Graph at 0x1a0f1e3908>,
#  <networkx.classes.graph.Graph at 0x1a0f1e38d0>,
#  <networkx.classes.graph.Graph at 0x1a0f1e3978>,
#  <networkx.classes.graph.Graph at 0x1a0f1e39b0>,
#  <networkx.classes.graph.Graph at 0x1a0f1e39e8>,
#  <networkx.classes.graph.Graph at 0x1a0f1e3a20>,
#  <networkx.classes.graph.Graph at 0x1a0f1e3a58>,
#  <networkx.classes.graph.Graph at 0x1a0f1e3940>,
#  <networkx.classes.graph.Graph at 0x1a0f1e3ac8>,
#  <networkx.classes.graph.Graph at 0x1a0f1e3b00>,
#  <networkx.classes.graph.Graph at 0x1a0f1e3b38>,
#  <networkx.classes.graph.Graph at 0x1a0f1e3b70>,
#  <networkx.classes.graph.Graph at 0x1a0f1e3ba8>,
#  <networkx.classes.graph.Graph at 0x1a0f1e3a90>,
#  <networkx.classes.graph.Graph at 0x1a0f1e37f0>,
#  <networkx.classes.graph.Graph at 0x1a0f1e3828>,
#  <networkx.classes.graph.Graph at 0x1a0f1e37b8>,
#  <networkx.classes.graph.Graph at 0x1a0f1e3be0>,
#  <networkx.classes.graph.Graph at 0x1a0f1e3c18>,
#  <networkx.classes.graph.Graph at 0x1a0f1e3c50>,
#  <networkx.classes.graph.Graph at 0x1a0f1e3c88>,
#  <networkx.classes.graph.Graph at 0x1a0f1e3860>,
#  <networkx.classes.graph.Graph at 0x1a0f1e3cc0>,
#  <networkx.classes.graph.Graph at 0x1a0f1e3d30>,
#  <networkx.classes.graph.Graph at 0x1a0f1e3d68>,
#  <networkx.classes.graph.Graph at 0x1a0f1e3da0>,
#  <networkx.classes.graph.Graph at 0x1a0f1e3dd8>,
#  <networkx.classes.graph.Graph at 0x1a0f1e3e10>,
#  <networkx.classes.graph.Graph at 0x1a0f1e3cf8>,
#  <networkx.classes.graph.Graph at 0x1a0f1e3e80>,
#  <networkx.classes.graph.Graph at 0x1a0f1e3eb8>,
#  <networkx.classes.graph.Graph at 0x1a0f1e3ef0>,
#  <networkx.classes.graph.Graph at 0x1a0f1e3e48>,
#  <networkx.classes.graph.Graph at 0x1a0f1e3f28>,
#  <networkx.classes.graph.Graph at 0x1a0f1e3f98>,
#  <networkx.classes.graph.Graph at 0x1a0f1e3f60>,
#  <networkx.classes.graph.Graph at 0x1a0f1e3fd0>,
#  <networkx.classes.graph.Graph at 0x1a0f0a3c88>,
#  <networkx.classes.graph.Graph at 0x1a0f0a3cc0>,
#  <networkx.classes.graph.Graph at 0x1a0f0a3240>,
#  <networkx.classes.graph.Graph at 0x107b09780>,
#  <networkx.classes.graph.Graph at 0x107b09f60>,
#  <networkx.classes.graph.Graph at 0x107b09fd0>,
#  <networkx.classes.graph.Graph at 0x107b09550>,
#  <networkx.classes.graph.Graph at 0x1a0f1d5b70>,
#  <networkx.classes.graph.Graph at 0x1a0f1d5da0>,
#  <networkx.classes.graph.Graph at 0x1a0f1d5eb8>,
#  <networkx.classes.graph.Graph at 0x1a0f1d5e10>,
#  <networkx.classes.graph.Graph at 0x1a0f1d5cf8>,
#  <networkx.classes.graph.Graph at 0x1a0f1d5c18>,
#  <networkx.classes.graph.Graph at 0x1a0f1d5e80>,
#  <networkx.classes.graph.Graph at 0x1a0f1d5cc0>,
#  <networkx.classes.graph.Graph at 0x1a0f1d5c88>,
#  <networkx.classes.graph.Graph at 0x1a0f1d5a58>,
#  <networkx.classes.graph.Graph at 0x1a0f1d5c50>,
#  <networkx.classes.graph.Graph at 0x1a0f1d5e48>,
#  <networkx.classes.graph.Graph at 0x1a0f1d5dd8>,
#  <networkx.classes.graph.Graph at 0x1a0f1d5a90>,
#  <networkx.classes.graph.Graph at 0x1a0f1d5fd0>,
#  <networkx.classes.graph.Graph at 0x1a0f1d5be0>,
#  <networkx.classes.graph.Graph at 0x1a0f1d5ac8>,
#  <networkx.classes.graph.Graph at 0x1a0f1d5f28>,
#  <networkx.classes.graph.Graph at 0x1a0f1d5d30>,
#  <networkx.classes.graph.Graph at 0x1a0f1d5b00>,
#  <networkx.classes.graph.Graph at 0x1a0f1d5d68>,
#  <networkx.classes.graph.Graph at 0x1a16de5080>,
#  <networkx.classes.graph.Graph at 0x1a16de5048>,
#  <networkx.classes.graph.Graph at 0x1a16de50b8>,
#  <networkx.classes.graph.Graph at 0x1a16de50f0>,
#  <networkx.classes.graph.Graph at 0x1a16de5160>,
#  <networkx.classes.graph.Graph at 0x1a16de5128>,
#  <networkx.classes.graph.Graph at 0x1a16de51d0>,
#  <networkx.classes.graph.Graph at 0x1a16de5198>,
#  <networkx.classes.graph.Graph at 0x1a16de5240>,
#  <networkx.classes.graph.Graph at 0x1a16de5278>,
#  <networkx.classes.graph.Graph at 0x1a16de5208>,
#  <networkx.classes.graph.Graph at 0x1a16de52b0>,
#  <networkx.classes.graph.Graph at 0x1a16de5320>,
#  <networkx.classes.graph.Graph at 0x1a16de52e8>,
#  <networkx.classes.graph.Graph at 0x1a16de5390>,
#  <networkx.classes.graph.Graph at 0x1a16de5358>,
#  <networkx.classes.graph.Graph at 0x1a16de5400>,
#  <networkx.classes.graph.Graph at 0x1a16de53c8>,
#  <networkx.classes.graph.Graph at 0x1a16de5470>,
#  <networkx.classes.graph.Graph at 0x1a16de5438>,
#  <networkx.classes.graph.Graph at 0x1a16de54a8>,
#  <networkx.classes.graph.Graph at 0x1a16de5518>,
#  <networkx.classes.graph.Graph at 0x1a16de54e0>,
#  <networkx.classes.graph.Graph at 0x1a16de5588>,
#  <networkx.classes.graph.Graph at 0x1a16de5550>,
#  <networkx.classes.graph.Graph at 0x1a16de55f8>,
#  <networkx.classes.graph.Graph at 0x1a16de55c0>,
#  <networkx.classes.graph.Graph at 0x1a16de5630>,
#  <networkx.classes.graph.Graph at 0x1a16de5668>,
#  <networkx.classes.graph.Graph at 0x1a16de56a0>,
#  <networkx.classes.graph.Graph at 0x1a16de5710>,
#  <networkx.classes.graph.Graph at 0x1a16de56d8>,
#  <networkx.classes.graph.Graph at 0x1a16de5780>,
#  <networkx.classes.graph.Graph at 0x1a16de57b8>,
#  <networkx.classes.graph.Graph at 0x1a16de57f0>,
#  <networkx.classes.graph.Graph at 0x1a16de5828>,
#  <networkx.classes.graph.Graph at 0x1a16de5860>,
#  <networkx.classes.graph.Graph at 0x1a16de5898>,
#  <networkx.classes.graph.Graph at 0x1a16de58d0>,
#  <networkx.classes.graph.Graph at 0x1a16de5748>,
#  <networkx.classes.graph.Graph at 0x1a16de5940>,
#  <networkx.classes.graph.Graph at 0x1a16de5978>,
#  <networkx.classes.graph.Graph at 0x1a16de59b0>,
#  <networkx.classes.graph.Graph at 0x1a16de59e8>,
#  <networkx.classes.graph.Graph at 0x1a16de5a20>,
#  <networkx.classes.graph.Graph at 0x1a16de5a58>,
#  <networkx.classes.graph.Graph at 0x1a16de5908>,
#  <networkx.classes.graph.Graph at 0x1a16de5a90>,
#  <networkx.classes.graph.Graph at 0x1a16de5b00>,
#  <networkx.classes.graph.Graph at 0x1a16de5ac8>,
#  <networkx.classes.graph.Graph at 0x1a16de5b70>,
#  <networkx.classes.graph.Graph at 0x1a16de5ba8>,
#  <networkx.classes.graph.Graph at 0x1a16de5be0>,
#  <networkx.classes.graph.Graph at 0x1a16de5c18>,
#  <networkx.classes.graph.Graph at 0x1a16de5c50>,
#  <networkx.classes.graph.Graph at 0x1a16de5c88>,
#  <networkx.classes.graph.Graph at 0x1a16de5cc0>,
#  <networkx.classes.graph.Graph at 0x1a16de5b38>,
#  <networkx.classes.graph.Graph at 0x1a16de5cf8>,
#  <networkx.classes.graph.Graph at 0x1a16de5d68>,
#  <networkx.classes.graph.Graph at 0x1a16de5da0>,
#  <networkx.classes.graph.Graph at 0x1a16de5d30>,
#  <networkx.classes.graph.Graph at 0x1a16de5dd8>,
#  <networkx.classes.graph.Graph at 0x1a16de5e10>,
#  <networkx.classes.graph.Graph at 0x1a16de5e80>,
#  <networkx.classes.graph.Graph at 0x1a16de5e48>,
#  <networkx.classes.graph.Graph at 0x1a16de5ef0>,
#  <networkx.classes.graph.Graph at 0x1a16de5f28>,
#  <networkx.classes.graph.Graph at 0x1a16de5f60>,
#  <networkx.classes.graph.Graph at 0x1a16de5f98>,
#  <networkx.classes.graph.Graph at 0x1a16de5fd0>,
#  <networkx.classes.graph.Graph at 0x1a16de5eb8>,
#  <networkx.classes.graph.Graph at 0x1a16e17048>,
#  <networkx.classes.graph.Graph at 0x1a16e170b8>,
#  <networkx.classes.graph.Graph at 0x1a16e170f0>,
#  <networkx.classes.graph.Graph at 0x1a16e17080>,
#  <networkx.classes.graph.Graph at 0x1a16e17160>,
#  <networkx.classes.graph.Graph at 0x1a16e17128>,
#  <networkx.classes.graph.Graph at 0x1a16e171d0>,
#  <networkx.classes.graph.Graph at 0x1a16e17208>,
#  <networkx.classes.graph.Graph at 0x1a16e17198>,
#  <networkx.classes.graph.Graph at 0x1a16e17278>,
#  <networkx.classes.graph.Graph at 0x1a16e17240>,
#  <networkx.classes.graph.Graph at 0x1a16e172b0>,
#  <networkx.classes.graph.Graph at 0x1a16e17320>,
#  <networkx.classes.graph.Graph at 0x1a16e17358>,
#  <networkx.classes.graph.Graph at 0x1a16e17390>,
#  <networkx.classes.graph.Graph at 0x1a16e173c8>,
#  <networkx.classes.graph.Graph at 0x1a16e172e8>,
#  <networkx.classes.graph.Graph at 0x1a16e17438>,
#  <networkx.classes.graph.Graph at 0x1a16e17400>,
#  <networkx.classes.graph.Graph at 0x1a16e174a8>,
#  <networkx.classes.graph.Graph at 0x1a16e174e0>,
#  <networkx.classes.graph.Graph at 0x1a16e17470>,
#  <networkx.classes.graph.Graph at 0x1a16e17550>,
#  <networkx.classes.graph.Graph at 0x1a16e17588>,
#  <networkx.classes.graph.Graph at 0x1a16e17518>,
#  <networkx.classes.graph.Graph at 0x1a16e175f8>,
#  <networkx.classes.graph.Graph at 0x1a16e17630>,
#  <networkx.classes.graph.Graph at 0x1a16e17668>,
#  <networkx.classes.graph.Graph at 0x1a16e176a0>,
#  <networkx.classes.graph.Graph at 0x1a16e176d8>,
#  <networkx.classes.graph.Graph at 0x1a16e17710>,
#  <networkx.classes.graph.Graph at 0x1a16e17748>,
#  <networkx.classes.graph.Graph at 0x1a16e17780>,
#  <networkx.classes.graph.Graph at 0x1a16e177b8>,
#  <networkx.classes.graph.Graph at 0x1a16e175c0>,
#  <networkx.classes.graph.Graph at 0x1a16e177f0>,
#  <networkx.classes.graph.Graph at 0x1a16e17860>,
#  <networkx.classes.graph.Graph at 0x1a16e17898>,
#  <networkx.classes.graph.Graph at 0x1a16e178d0>,
#  <networkx.classes.graph.Graph at 0x1a16e17908>,
#  <networkx.classes.graph.Graph at 0x1a16e17940>,
#  <networkx.classes.graph.Graph at 0x1a16e17828>,
#  <networkx.classes.graph.Graph at 0x1a16e179b0>,
#  <networkx.classes.graph.Graph at 0x1a16e17978>,
#  <networkx.classes.graph.Graph at 0x1a16e17a20>,
#  <networkx.classes.graph.Graph at 0x1a16e17a58>,
#  <networkx.classes.graph.Graph at 0x1a16e17a90>,
#  <networkx.classes.graph.Graph at 0x1a16e17ac8>,
#  <networkx.classes.graph.Graph at 0x1a16e17b00>,
#  <networkx.classes.graph.Graph at 0x1a16e17b38>,
#  <networkx.classes.graph.Graph at 0x1a16e17b70>,
#  <networkx.classes.graph.Graph at 0x1a16e17ba8>,
#  <networkx.classes.graph.Graph at 0x1a16e179e8>,
#  <networkx.classes.graph.Graph at 0x1a16e17c18>,
#  <networkx.classes.graph.Graph at 0x1a16e17c50>,
#  <networkx.classes.graph.Graph at 0x1a16e17c88>,
#  <networkx.classes.graph.Graph at 0x1a16e17be0>,
#  <networkx.classes.graph.Graph at 0x1a16e17cf8>,
#  <networkx.classes.graph.Graph at 0x1a16e17d30>,
#  <networkx.classes.graph.Graph at 0x1a16e17d68>,
#  <networkx.classes.graph.Graph at 0x1a16e17da0>,
#  <networkx.classes.graph.Graph at 0x1a16e17cc0>,
#  <networkx.classes.graph.Graph at 0x1a16e17dd8>,
#  <networkx.classes.graph.Graph at 0x1a16e17e10>,
#  <networkx.classes.graph.Graph at 0x1a16e17e48>,
#  <networkx.classes.graph.Graph at 0x1a16e17eb8>,
#  <networkx.classes.graph.Graph at 0x1a16e17ef0>,
#  <networkx.classes.graph.Graph at 0x1a16e17e80>,
#  <networkx.classes.graph.Graph at 0x1a16e17f60>,
#  <networkx.classes.graph.Graph at 0x1a16e17f98>,
#  <networkx.classes.graph.Graph at 0x1a16e17f28>,
#  <networkx.classes.graph.Graph at 0x1a16e17fd0>,
#  <networkx.classes.graph.Graph at 0x1a16e51080>,
#  <networkx.classes.graph.Graph at 0x1a16e510b8>,
#  <networkx.classes.graph.Graph at 0x1a16e510f0>,
#  <networkx.classes.graph.Graph at 0x1a16e51128>,
#  <networkx.classes.graph.Graph at 0x1a16e51048>,
#  <networkx.classes.graph.Graph at 0x1a16e51160>,
#  <networkx.classes.graph.Graph at 0x1a16e511d0>,
#  <networkx.classes.graph.Graph at 0x1a16e51208>,
#  <networkx.classes.graph.Graph at 0x1a16e51240>,
#  <networkx.classes.graph.Graph at 0x1a16e51278>,
#  <networkx.classes.graph.Graph at 0x1a16e51198>,
#  <networkx.classes.graph.Graph at 0x1a16e512e8>,
#  <networkx.classes.graph.Graph at 0x1a16e51320>,
#  <networkx.classes.graph.Graph at 0x1a16e512b0>,
#  <networkx.classes.graph.Graph at 0x1a16e51390>,
#  <networkx.classes.graph.Graph at 0x1a16e513c8>,
#  <networkx.classes.graph.Graph at 0x1a16e51400>,
#  <networkx.classes.graph.Graph at 0x1a16e51438>,
#  <networkx.classes.graph.Graph at 0x1a16e51358>,
#  <networkx.classes.graph.Graph at 0x1a16e514a8>,
#  <networkx.classes.graph.Graph at 0x1a16e514e0>,
#  <networkx.classes.graph.Graph at 0x1a16e51470>,
#  <networkx.classes.graph.Graph at 0x1a16e51550>,
#  <networkx.classes.graph.Graph at 0x1a16e51588>,
#  <networkx.classes.graph.Graph at 0x1a16e515c0>,
#  <networkx.classes.graph.Graph at 0x1a16e515f8>,
#  <networkx.classes.graph.Graph at 0x1a16e51630>,
#  <networkx.classes.graph.Graph at 0x1a16e51518>,
#  <networkx.classes.graph.Graph at 0x1a16e516a0>,
#  <networkx.classes.graph.Graph at 0x1a16e51668>,
#  <networkx.classes.graph.Graph at 0x1a16e516d8>,
#  <networkx.classes.graph.Graph at 0x1a16e51748>,
#  <networkx.classes.graph.Graph at 0x1a16e51780>,
#  <networkx.classes.graph.Graph at 0x1a16e51710>,
#  <networkx.classes.graph.Graph at 0x1a16e517f0>,
#  <networkx.classes.graph.Graph at 0x1a16e51828>,
#  <networkx.classes.graph.Graph at 0x1a16e51860>,
#  <networkx.classes.graph.Graph at 0x1a16e51898>,
#  <networkx.classes.graph.Graph at 0x1a16e517b8>,
#  <networkx.classes.graph.Graph at 0x1a16e518d0>,
#  <networkx.classes.graph.Graph at 0x1a16e51940>,
#  <networkx.classes.graph.Graph at 0x1a16e51908>,
#  <networkx.classes.graph.Graph at 0x1a16e51978>,
#  <networkx.classes.graph.Graph at 0x1a16e519e8>,
#  <networkx.classes.graph.Graph at 0x1a16e519b0>,
#  <networkx.classes.graph.Graph at 0x1a16e51a20>,
#  <networkx.classes.graph.Graph at 0x1a16e51a90>,
#  <networkx.classes.graph.Graph at 0x1a16e51ac8>,
#  <networkx.classes.graph.Graph at 0x1a16e51b00>,
#  <networkx.classes.graph.Graph at 0x1a16e51b38>,
#  <networkx.classes.graph.Graph at 0x1a16e51b70>,
#  <networkx.classes.graph.Graph at 0x1a16e51ba8>,
#  <networkx.classes.graph.Graph at 0x1a16e51be0>,
#  <networkx.classes.graph.Graph at 0x1a16e51c18>,
#  <networkx.classes.graph.Graph at 0x1a16e51c50>,
#  <networkx.classes.graph.Graph at 0x1a16e51c88>,
#  <networkx.classes.graph.Graph at 0x1a16e51cc0>,
#  <networkx.classes.graph.Graph at 0x1a16e51cf8>,
#  <networkx.classes.graph.Graph at 0x1a16e51a58>,
#  <networkx.classes.graph.Graph at 0x1a16e51d68>]

# %%
H=graphs[0]

# %%
len(H)
# Out:
# 17903

# %%
print(len(G)-len(H))
# Out:
# 869

# %%
print("Check that the graph is now connected")
nx.number_connected_components(H)
# Out:
# Check that the graph is now connected
# 1

# %% [markdown]
# ## Global clustering coefficient

# %% [markdown]
# The global clustering coefficient measures the number of triangles in the network and it's defined as:
# <center>
# $C_\Delta = \frac{3 \times \text{triangles}}{\text{triplets}}$
# </center>

# %%
nx.triangles(H)
# Out:
# {3: 625,
#  4: 1,
#  65540: 12,
#  65541: 10,
#  32776: 60,
#  32777: 21,
#  65546: 119,
#  98315: 365,
#  32778: 1,
#  13: 16,
#  98318: 693,
#  98319: 3,
#  15: 0,
#  17: 0,
#  16: 1,
#  131091: 2837,
#  32787: 130,
#  98325: 92,
#  98326: 6,
#  32791: 580,
#  26: 12,
#  27: 0,
#  65564: 334,
#  32796: 7,
#  65566: 45,
#  30: 2357,
#  65568: 10,
#  65567: 45,
#  65569: 45,
#  65571: 21,
#  98340: 9,
#  32799: 3,
#  35: 3,
#  65570: 3,
#  98345: 317,
#  98346: 153,
#  43: 231,
#  41: 11,
#  98349: 55,
#  98348: 3,
#  131121: 2836,
#  98354: 13,
#  131122: 3,
#  98356: 3,
#  131123: 3,
#  98358: 5,
#  131126: 11,
#  131127: 6,
#  57: 114,
#  65595: 489,
#  131133: 1779,
#  65597: 1,
#  65599: 28,
#  32840: 469,
#  73: 3,
#  65610: 54,
#  65613: 335,
#  80: 2,
#  65620: 21,
#  84: 4,
#  86: 157,
#  88: 352,
#  65627: 28,
#  65628: 0,
#  65629: 406,
#  95: 5,
#  131167: 616,
#  65637: 32,
#  65638: 55,
#  102: 11,
#  65642: 1933,
#  65643: 45,
#  98412: 379,
#  106: 19,
#  131180: 97,
#  98417: 325,
#  114: 1545,
#  117: 915,
#  119: 94,
#  120: 6,
#  65657: 19,
#  124: 3,
#  98431: 21,
#  98432: 28,
#  131204: 1877,
#  98439: 348,
#  131209: 980,
#  98441: 21,
#  131211: 3,
#  65676: 874,
#  131212: 3,
#  131215: 2,
#  98449: 72,
#  131217: 3,
#  131221: 2488,
#  131222: 3,
#  98456: 29,
#  155: 74,
#  157: 19,
#  98463: 12,
#  131234: 940,
#  164: 506,
#  131237: 11,
#  98471: 61,
#  172: 23,
#  98477: 14,
#  65713: 2256,
#  178: 214,
#  179: 0,
#  65718: 111,
#  65719: 28,
#  184: 11,
#  65723: 41,
#  189: 42,
#  131263: 72,
#  131266: 439,
#  131272: 198,
#  131273: 6,
#  98506: 491,
#  131279: 338,
#  98511: 63,
#  98512: 10,
#  131281: 29,
#  65751: 107,
#  65753: 380,
#  131292: 448,
#  98529: 262,
#  65763: 53,
#  98532: 236,
#  229: 972,
#  131302: 14,
#  131303: 10,
#  98536: 4,
#  231: 0,
#  98540: 19,
#  131309: 42,
#  98541: 406,
#  98545: 378,
#  242: 3,
#  131315: 856,
#  131320: 489,
#  131322: 6,
#  131323: 1,
#  131324: 15,
#  131326: 3,
#  131329: 107,
#  65794: 20,
#  131330: 1,
#  65796: 6,
#  65795: 10,
#  65798: 6,
#  65799: 231,
#  65800: 3,
#  65801: 666,
#  98571: 956,
#  131342: 9,
#  33040: 2759,
#  131344: 3,
#  33042: 8,
#  276: 54,
#  277: 0,
#  278: 36,
#  65814: 133,
#  131352: 67,
#  65817: 11,
#  98586: 451,
#  283: 21,
#  284: 3,
#  33053: 2115,
#  98590: 136,
#  65822: 1727,
#  98589: 78,
#  98588: 0,
#  65818: 28,
#  291: 196,
#  289: 462,
#  293: 1035,
#  65829: 215,
#  131361: 50,
#  296: 45,
#  294: 3,
#  131370: 9,
#  131371: 1,
#  33068: 210,
#  295: 66,
#  65838: 11,
#  302: 10,
#  304: 136,
#  65841: 10,
#  131375: 3,
#  131376: 21,
#  131373: 6,
#  303: 0,
#  310: 10,
#  131385: 221,
#  98621: 822,
#  131389: 29,
#  131391: 1898,
#  319: 205,
#  321: 0,
#  320: 6,
#  131396: 277,
#  98629: 30,
#  131398: 21,
#  33095: 122,
#  98631: 924,
#  131400: 28,
#  131402: 3,
#  98635: 5,
#  98636: 66,
#  98637: 990,
#  334: 6,
#  98639: 215,
#  333: 18,
#  131409: 567,
#  33099: 10,
#  335: 0,
#  33108: 109,
#  33109: 55,
#  131414: 0,
#  98643: 12,
#  98645: 1,
#  98647: 168,
#  346: 21,
#  342: 14,
#  98651: 1,
#  349: 122,
#  98654: 4,
#  350: 1,
#  352: 48,
#  65889: 565,
#  353: 36,
#  357: 172,
#  33126: 151,
#  65895: 22,
#  33127: 45,
#  33131: 0,
#  33132: 3,
#  33135: 9,
#  33139: 1389,
#  33141: 14,
#  131451: 348,
#  384: 284,
#  33152: 4,
#  386: 1485,
#  385: 66,
#  65927: 391,
#  65928: 1,
#  98698: 427,
#  131468: 127,
#  131469: 10,
#  131470: 6,
#  131471: 66,
#  131472: 1,
#  65937: 184,
#  65938: 190,
#  65939: 120,
#  98709: 5,
#  98712: 32,
#  98714: 12,
#  411: 40,
#  65947: 26,
#  33181: 238,
#  65949: 143,
#  98721: 4,
#  418: 27,
#  131491: 83,
#  420: 299,
#  98725: 378,
#  33189: 104,
#  423: 6,
#  421: 1,
#  425: 3,
#  33190: 1,
#  98731: 30,
#  131493: 28,
#  98724: 12,
#  427: 3,
#  98735: 10,
#  98736: 1,
#  131496: 447,
#  33202: 57,
#  33203: 0,
#  98732: 15,
#  33205: 3,
#  65977: 188,
#  65978: 15,
#  65980: 6,
#  65982: 62,
#  131519: 77,
#  65983: 6,
#  65984: 21,
#  131520: 15,
#  65986: 10,
#  98756: 23,
#  65989: 256,
#  131525: 15,
#  98759: 115,
#  33224: 6,
#  98761: 54,
#  131527: 6,
#  131523: 15,
#  461: 2019,
#  98765: 162,
#  463: 861,
#  131534: 13,
#  465: 738,
#  98770: 40,
#  98771: 120,
#  131536: 6,
#  131541: 62,
#  66006: 540,
#  131542: 6,
#  98776: 31,
#  98777: 21,
#  66010: 169,
#  98772: 21,
#  98780: 22,
#  131544: 7,
#  66018: 226,
#  66022: 8,
#  66023: 21,
#  492: 418,
#  131565: 396,
#  494: 826,
#  496: 7,
#  66033: 5,
#  497: 1,
#  498: 0,
#  66036: 1078,
#  501: 0,
#  503: 804,
#  66039: 0,
#  131575: 378,
#  66040: 21,
#  507: 6,
#  508: 78,
#  506: 2,
#  131587: 23,
#  131588: 153,
#  131589: 21,
#  518: 21,
#  517: 44,
#  131592: 820,
#  131593: 66,
#  66058: 209,
#  131591: 1,
#  131596: 3,
#  66061: 0,
#  131594: 6,
#  66059: 1,
#  529: 1426,
#  530: 10,
#  33302: 369,
#  535: 1556,
#  66075: 9,
#  542: 364,
#  66079: 4,
#  543: 3,
#  66082: 99,
#  98853: 111,
#  66086: 7,
#  555: 440,
#  560: 3,
#  98865: 82,
#  66098: 15,
#  561: 1,
#  66100: 17,
#  566: 11,
#  98871: 49,
#  131639: 55,
#  98872: 6,
#  98873: 3,
#  569: 231,
#  572: 15,
#  573: 91,
#  568: 1,
#  131647: 133,
#  131649: 6,
#  131650: 3,
#  131651: 1,
#  577: 6,
#  131654: 158,
#  33351: 1806,
#  98896: 800,
#  33362: 971,
#  33364: 1128,
#  598: 370,
#  33367: 214,
#  599: 253,
#  603: 55,
#  604: 3,
#  33380: 12,
#  66157: 606,
#  98926: 71,
#  623: 39,
#  66158: 3,
#  66160: 3,
#  98933: 477,
#  131704: 1718,
#  33400: 60,
#  33401: 3,
#  635: 28,
#  98940: 31,
#  636: 0,
#  98941: 136,
#  33402: 91,
#  98944: 8,
#  640: 48,
#  131713: 24,
#  642: 153,
#  98948: 6,
#  645: 407,
#  98949: 91,
#  98951: 1035,
#  131717: 993,
#  646: 3,
#  98954: 8,
#  98947: 0,
#  98956: 9,
#  98952: 6,
#  654: 54,
#  655: 3,
#  98957: 3,
#  98961: 1,
#  98962: 406,
#  33428: 341,
#  33429: 15,
#  661: 5,
#  33431: 6,
#  66200: 73,
#  131737: 99,
#  98970: 177,
#  665: 8,
#  33430: 0,
#  131741: 4,
#  131742: 6,
#  66205: 1062,
#  98980: 194,
#  98981: 66,
#  98983: 4,
#  680: 21,
#  33448: 55,
#  66222: 180,
#  66232: 326,
#  66233: 3,
#  66234: 105,
#  66241: 4,
#  66245: 10,
#  99023: 1835,
#  99024: 10,
#  66256: 138,
#  722: 1238,
#  99028: 188,
#  99029: 78,
#  725: 0,
#  99031: 10,
#  728: 3,
#  729: 6,
#  730: 10,
#  66267: 28,
#  33500: 2584,
#  33504: 5,
#  66274: 44,
#  33507: 3,
#  131813: 3795,
#  131814: 1,
#  33509: 3,
#  33513: 3,
#  746: 2,
#  747: 45,
#  748: 0,
#  749: 630,
#  751: 1,
#  754: 10,
#  33526: 533,
#  762: 1,
#  131835: 113,
#  33532: 64,
#  66300: 52,
#  766: 141,
#  764: 1,
#  131840: 54,
#  768: 2,
#  131843: 130,
#  772: 12,
#  66309: 47,
#  773: 28,
#  66311: 465,
#  66310: 406,
#  131849: 114,
#  131850: 0,
#  99086: 1868,
#  782: 95,
#  784: 1378,
#  131856: 10,
#  131855: 3,
#  783: 3,
#  131860: 0,
#  131861: 0,
#  789: 53,
#  790: 10,
#  791: 3,
#  131857: 406,
#  131866: 2055,
#  131869: 13,
#  99104: 3003,
#  66336: 376,
#  99105: 15,
#  99107: 46,
#  811: 490,
#  812: 378,
#  813: 10,
#  66350: 33,
#  815: 122,
#  816: 45,
#  66351: 0,
#  66356: 3,
#  99126: 126,
#  822: 1403,
#  824: 439,
#  99129: 267,
#  33593: 343,
#  99131: 105,
#  66367: 814,
#  66368: 528,
#  66369: 10,
#  33604: 59,
#  837: 2379,
#  839: 180,
#  99144: 104,
#  33609: 3,
#  131914: 94,
#  843: 15,
#  33610: 1,
#  33615: 148,
#  66396: 744,
#  99165: 203,
#  66401: 1019,
#  99170: 9,
#  33635: 411,
#  867: 9,
#  131940: 130,
#  33636: 6,
#  871: 607,
#  872: 10,
#  99177: 6,
#  99178: 351,
#  874: 15,
#  99180: 0,
#  66413: 109,
#  99179: 1,
#  33641: 444,
#  33643: 6,
#  33650: 3,
#  884: 262,
#  887: 3,
#  99193: 297,
#  66426: 368,
#  889: 0,
#  33659: 36,
#  891: 6,
#  66430: 381,
#  895: 34,
#  66428: 319,
#  33657: 16,
#  131967: 16,
#  896: 6,
#  898: 15,
#  897: 0,
#  66438: 23,
#  131975: 76,
#  904: 11,
#  66439: 3,
#  99211: 323,
#  131980: 91,
#  131981: 10,
#  131982: 1,
#  131979: 253,
#  66448: 11,
#  131986: 162,
#  99219: 36,
#  916: 1493,
#  131988: 45,
#  66454: 19,
#  66451: 163,
#  66456: 7,
#  131993: 484,
#  131987: 153,
#  66459: 36,
#  33692: 25,
#  66461: 9,
#  99230: 8,
#  33686: 4,
#  66464: 21,
#  66465: 3,
#  66469: 45,
#  99239: 2134,
#  99240: 28,
#  99242: 2,
#  33709: 1613,
#  99251: 75,
#  132020: 491,
#  132021: 3,
#  99254: 1251,
#  132023: 1,
#  132024: 0,
#  99258: 6,
#  99259: 1,
#  99260: 3,
#  99263: 124,
#  66502: 1076,
#  132043: 32,
#  66511: 516,
#  66514: 1035,
#  66515: 6,
#  66518: 25,
#  33751: 23,
#  33752: 0,
#  33753: 10,
#  66522: 409,
#  33757: 28,
#  66526: 351,
#  66525: 712,
#  66527: 630,
#  33760: 15,
#  33759: 168,
#  33763: 293,
#  66535: 352,
#  66538: 12,
#  132075: 625,
#  66539: 0,
#  132076: 1,
#  132077: 3,
#  66544: 34,
#  33777: 13,
#  33778: 231,
#  33779: 351,
#  33781: 60,
#  66553: 933,
#  66555: 1,
#  99324: 1525,
#  99327: 56,
#  99332: 28,
#  33797: 64,
#  33798: 120,
#  132104: 57,
#  132105: 10,
#  132106: 0,
#  33805: 935,
#  99347: 2106,
#  99348: 820,
#  99349: 28,
#  132121: 35,
#  99359: 16,
#  99361: 1485,
#  33830: 370,
#  33832: 1,
#  33833: 55,
#  99370: 310,
#  66602: 13,
#  66605: 1,
#  99374: 2365,
#  66607: 23,
#  33840: 1371,
#  66608: 15,
#  99386: 8,
#  33851: 8,
#  1086: 3006,
#  33855: 10,
#  33854: 7,
#  1095: 4,
#  66632: 62,
#  66633: 1,
#  66634: 105,
#  1099: 6,
#  66636: 121,
#  132173: 375,
#  66638: 15,
#  1102: 15,
#  66637: 21,
#  1105: 6,
#  1112: 1,
#  132185: 115,
#  33883: 362,
#  1116: 12,
#  33885: 253,
#  33886: 10,
#  1119: 1,
#  1120: 0,
#  1121: 15,
#  33884: 3,
#  33887: 1,
#  1122: 6,
#  1123: 1,
#  99431: 862,
#  99432: 6,
#  1127: 5,
#  1128: 3,
#  132206: 646,
#  1134: 69,
#  33908: 876,
#  33909: 1,
#  99449: 328,
#  66682: 368,
#  66683: 15,
#  99450: 0,
#  132221: 55,
#  132217: 79,
#  99455: 465,
#  99456: 351,
#  66685: 105,
#  66690: 7,
#  1155: 2522,
#  99454: 146,
#  33925: 279,
#  99462: 23,
#  33926: 6,
#  132226: 1133,
#  33921: 48,
#  1158: 190,
#  66698: 281,
#  99466: 25,
#  99469: 78,
#  99467: 10,
#  33932: 80,
#  1163: 5,
#  99470: 28,
#  99472: 27,
#  99468: 0,
#  99474: 18,
#  66707: 199,
#  132244: 158,
#  66709: 3,
#  99476: 3,
#  66711: 15,
#  33941: 18,
#  99481: 30,
#  99482: 45,
#  1178: 192,
#  132247: 3,
#  33943: 11,
#  33945: 10,
#  33944: 1,
#  1186: 1043,
#  1187: 3,
#  66724: 457,
#  1188: 28,
#  66725: 0,
#  66727: 10,
#  66728: 630,
#  66726: 6,
#  66730: 45,
#  99499: 6,
#  99500: 10,
#  66733: 480,
#  66734: 21,
#  99504: 15,
#  99505: 28,
#  66740: 1842,
#  33973: 3383,
#  66741: 36,
#  132282: 122,
#  99514: 102,
#  132284: 21,
#  132285: 1,
#  66750: 81,
#  33983: 1798,
#  99520: 512,
#  132286: 435,
#  1217: 36,
#  1218: 3,
#  66756: 206,
#  66757: 1,
#  99521: 10,
#  132295: 112,
#  1216: 17,
#  66761: 1,
#  33985: 21,
#  66760: 2,
#  66766: 14,
#  1231: 559,
#  66768: 171,
#  66767: 78,
#  66769: 136,
#  99539: 1579,
#  1235: 257,
#  66770: 3,
#  1239: 3,
#  132312: 181,
#  34009: 677,
#  132313: 6,
#  1240: 15,
#  99548: 238,
#  34013: 10,
#  132316: 1,
#  34011: 637,
#  1250: 133,
#  34018: 5,
#  34021: 34,
#  66791: 208,
#  1255: 268,
#  34023: 20,
#  99562: 15,
#  99561: 49,
#  99566: 4,
#  99568: 70,
#  34033: 1,
#  34032: 12,
#  66803: 86,
#  1267: 2,
#  99570: 0,
#  132342: 63,
#  99575: 10,
#  99572: 0,
#  132347: 10,
#  34051: 39,
#  66826: 1406,
#  132364: 15,
#  132368: 41,
#  99601: 226,
#  34066: 1822,
#  132369: 6,
#  34067: 0,
#  132373: 4,
#  132374: 3,
#  132376: 210,
#  66840: 1660,
#  34072: 2,
#  132380: 1,
#  99613: 32,
#  99617: 6,
#  132387: 26,
#  34085: 84,
#  99621: 1,
#  132390: 16,
#  99622: 1,
#  34090: 623,
#  99627: 0,
#  1324: 3217,
#  34097: 285,
#  99634: 91,
#  34101: 2,
#  1334: 484,
#  66875: 91,
#  1339: 18,
#  1341: 31,
#  34110: 791,
#  34111: 3,
#  66880: 87,
#  34107: 17,
#  66882: 3,
#  66883: 3,
#  34114: 1,
#  1351: 124,
#  1356: 580,
#  34124: 8,
#  34127: 49,
#  1366: 77,
#  1367: 10,
#  1368: 15,
#  1369: 0,
#  1370: 45,
#  1372: 7,
#  132445: 1246,
#  1374: 6,
#  132447: 1,
#  99690: 458,
#  132469: 272,
#  1399: 648,
#  1400: 0,
#  66946: 380,
#  1411: 20,
#  66947: 91,
#  99717: 1034,
#  99718: 990,
#  1418: 6,
#  132492: 1480,
#  34200: 1028,
#  1436: 119,
#  99741: 372,
#  34206: 3,
#  34207: 6,
#  34205: 1,
#  1439: 6,
#  1444: 35,
#  1446: 1,
#  34218: 23,
#  99755: 96,
#  1451: 5,
#  132525: 389,
#  1453: 7,
#  132527: 7,
#  132528: 3,
#  1456: 15,
#  34226: 15,
#  66995: 1272,
#  66996: 0,
#  99765: 40,
#  1458: 3,
#  34231: 9,
#  132535: 20,
#  1461: 12,
#  1466: 1,
#  99774: 3,
#  1482: 265,
#  99793: 54,
#  99798: 18,
#  67032: 458,
#  34265: 1056,
#  34266: 171,
#  99801: 207,
#  1500: 212,
#  1501: 6,
#  67034: 28,
#  34270: 26,
#  132576: 53,
#  99802: 0,
#  34267: 3,
#  1507: 6,
#  298: 3,
#  1509: 0,
#  1510: 6,
#  1513: 28,
#  1516: 21,
#  132589: 119,
#  1518: 33,
#  1519: 136,
#  99825: 1804,
#  132594: 991,
#  67060: 327,
#  132599: 12,
#  67064: 6,
#  99833: 17,
#  67068: 0,
#  99841: 36,
#  132614: 172,
#  132615: 1,
#  132617: 3,
#  132619: 11,
#  132620: 0,
#  132621: 10,
#  132623: 35,
#  34319: 438,
#  67090: 1057,
#  1556: 191,
#  132629: 108,
#  132630: 231,
#  1558: 15,
#  1559: 1,
#  132633: 10,
#  132631: 21,
#  132632: 0,
#  34332: 51,
#  34333: 28,
#  99870: 1409,
#  99874: 7,
#  34340: 223,
#  67108: 82,
#  99877: 602,
#  67109: 1,
#  1575: 155,
#  99878: 3,
#  99882: 1,
#  99879: 28,
#  99883: 15,
#  1582: 95,
#  67122: 305,
#  67123: 6,
#  1589: 80,
#  67126: 11,
#  132663: 1207,
#  67127: 6,
#  99898: 22,
#  132669: 14,
#  67134: 47,
#  67135: 6,
#  67137: 1,
#  1602: 75,
#  67139: 153,
#  1604: 3,
#  99908: 114,
#  67141: 5,
#  132679: 1174,
#  67143: 0,
#  132680: 1,
#  67147: 150,
#  99916: 9,
#  67148: 10,
#  34387: 1622,
#  132692: 6,
#  67157: 98,
#  67158: 6,
#  34391: 9,
#  132693: 6,
#  1625: 482,
#  99930: 43,
#  67163: 42,
#  99923: 1,
#  132697: 6,
#  ...}

# %% [markdown]
# How many triangles are there in the whole network?

# %%
tt=sum(list(nx.triangles(H).values()))

# %%
tt/3
# Out:
# 1350014.0

# %% [markdown]
# The transitivity is the fraction of all possible triangles in the network.

# %%
nx.transitivity(H)
# Out:
# 0.31777791273391154

# %% [markdown]
# ## Average clustering coefficient
# As an alternative to the global clustering coefficient, the overall level of clustering in a network is measured by Watts and Strogatz as the average of the local clustering coefficients of all the vertices $n$:
#
# <center>
# $\bar{C} = \frac{1}{n}\sum_{i=1}^{n} C_i.$
# </center>
#
# It is worth noting that this metric places more weight on the low degree nodes, while the transitivity ratio places more weight on the high degree nodes. In fact, a weighted average where each local clustering score is weighted by $k_i(k_i-1)$ is identical to the global clustering coefficient.

# %%
print("The average clustering coefficient of H is")
nx.average_clustering(H)
# Out:
# The average clustering coefficient of H is
# 0.6328232091518615

# %% [markdown]
# ## Average sorthest path length
# #### Warning! Calculating the shortest paths is intensive!

# %% [markdown]
# The graph is small world.

# %%
nx.average_shortest_path_length(H)
# Out:
# 4.194011768617203

# %%
math.log(len(H))
# Out:
# 9.792723575551273

# %% [markdown]
# ### Compare the results with a random ER network

# %% [markdown]
# We generate a random Erdos-Renyi graph with same average connectivity of H, i.e. same number of nodes and edges.

# %%
nnodes=18000
plink=0.00122

ER=nx.fast_gnp_random_graph(nnodes, plink)

# %%
nx.is_connected(ER)
# Out:
# True

# %%
print("The ER graph has", len(ER), "nodes")
print("and",len(ER.edges()),"edges")
# Out:
# The ER graph has 18000 nodes
# and 197159 edges

# %%
print("The average clustering coefficient of ER is")
nx.average_clustering(ER)
# Out:
# The average clustering coefficient of ER is
# 0.0012458203772162926

# %%
print(sum(list(nx.triangles(ER).values()))/3)
# Out:
# 1790.0

# %% [markdown]
# The ER graph is also small world!

# %%
nx.average_shortest_path_length(ER)
# Out:
# 3.5226608391824237

# %% [markdown]
# ### Compare the results with a random AB network

# %%
AB=nx.barabasi_albert_graph(18000,11)

# %%
print("The AB graph has", len(AB), "nodes")
print("and",len(AB.edges()),"edges")
# Out:
# The AB graph has 18000 nodes
# and 197879 edges

# %%
from collections import Counter 
degrees=dict(AB.degree()).values()
c=Counter(degrees)

# %%
import powerlaw as pwl

# %%
plt.figure(figsize=(10,7))
x=[]
y=[]
for i in sorted(c):   
    x.append(i)
    y.append(float(c[i])/len(AB))

    
plt.plot(np.array(x),np.array(y))
pwl.plot_pdf(list(degrees))

plt.xlabel('$k$', fontsize=18)
plt.ylabel('$P(k)$', fontsize=18)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.yscale('log')
plt.xscale('log')
plt.axis([10,1000,0.0000001,1])
plt.show()

# %%
fit_function = pwl.Fit(list(degrees), xmin=11)
# Out:
# /anaconda/envs/py36/lib/python3.6/site-packages/powerlaw.py:697: RuntimeWarning: invalid value encountered in true_divide
#   (Theoretical_CDF * (1 - Theoretical_CDF))

# %%
fit_function.power_law.alpha
# Out:
# /anaconda/envs/py36/lib/python3.6/site-packages/powerlaw.py:697: RuntimeWarning: invalid value encountered in true_divide
#   (Theoretical_CDF * (1 - Theoretical_CDF))
# 3.054072064223424

# %%
fit_function.power_law.sigma
# Out:
# 0.0153101492209563

# %%
fit_function.power_law.xmin
# Out:
# 11.0

# %%
print("The average clustering coefficient of AB is")
nx.average_clustering(AB)
# Out:
# The average clustering coefficient of AB is
# 0.007411233943768794

# %%
print("The number of triangles is ", sum(list(nx.triangles(AB).values()))/3)
# Out:
# The number of triangles is  22544.0

# %% [markdown]
# The AB network is also small-world.

# %%
nx.average_shortest_path_length(AB)
# Out:
# 3.1350227852164627

# %% [markdown]
# ### Compare the results with a random WS network

# %%
WS=nx.connected_watts_strogatz_graph(18000,23,0.2,50)

# %%
print("The WS graph has", len(WS), "nodes")
print("and",len(WS.edges()),"edges")
# Out:
# The WS graph has 18000 nodes
# and 198000 edges

# %%
nx.is_connected(WS)
# Out:
# True

# %%
ws_degrees=(dict(WS.degree()).values())

# %%
plt.figure(figsize=(10,7))
plt.hist(ws_degrees, bins=10)
plt.xlabel('$k$', fontsize=18)
plt.ylabel('$Freq.$', fontsize=18)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
# Out:
# (array([   0., 1000., 2000., 3000., 4000., 5000., 6000., 7000., 8000.]),
#  <a list of 9 Text yticklabel objects>)

# %%
print("The average clustering coefficient of WS is")
nx.average_clustering(WS)
# Out:
# The average clustering coefficient of WS is
# 0.3671866017581912

# %% [markdown]
# The Watt-Strogatz network is still small-world but with high clustering.

# %%
nx.average_shortest_path_length(WS)
# Out:
# 4.034229846102561

# %% [markdown]
# ## Closeness Centrality

# %% [markdown]
# In connected graphs there is a natural distance metric between all pairs of nodes, defined by the length of their shortest paths.
# The '''farness''' of a node ''x'' is defined as the sum of its distances from all other nodes, and its closeness was defined by Bavelas as the reciprocal of the farness that is:
#
#
# <center>
# $C(x)= \frac{1}{\sum_y d(y,x)}.$
# </center>
#
#
# Thus, the more central a node is the lower its total distance from all other nodes. Note that taking distances ''from'' or ''to'' all other nodes is irrelevant in undirected graphs, whereas in directed graphs distances ''to'' a node are considered a more meaningful measure of centrality, as in general (e.g., in, the web) a node has little control over its incoming links.

# %% [markdown]
# #### Be careful! Computing all the distances between pair of nodes can be intensive.

# %%
close_centr=nx.closeness_centrality(H)

# %%
print(close_centr)
# Out:
# {3: 0.23028930882334023, 4: 0.14656231067738607, 65540: 0.23372282786082643, 65541: 0.24392304338347504, 32776: 0.27964010122153143, 32777: 0.2582553123963127, 65546: 0.24103945065302276, 98315: 0.2660345954942638, 32778: 0.14952599707663394, 13: 0.2509919383105503, 98318: 0.25480009678475357, 98319: 0.20681369207841868, 15: 0.20731424865666112, 17: 0.22733564453249014, 16: 0.19450661683217801, 131091: 0.282459489736348, 32787: 0.2603889397972393, 98325: 0.2566668578310489, 98326: 0.22875324243856937, 32791: 0.29280340202813215, 26: 0.23255693111108225, 27: 0.2189365032775658, 65564: 0.24621774770314134, 32796: 0.22133478400633022, 65566: 0.27036578367112696, 30: 0.29125044740181566, 65568: 0.2324270987510062, 65567: 0.262723803933079, 65569: 0.2555895034407927, 65571: 0.25273530698967994, 98340: 0.24469321086371154, 32799: 0.20112572885887944, 35: 0.16834206294725557, 65570: 0.1487976992959912, 98345: 0.2641932675137616, 98346: 0.2758355033050338, 43: 0.26816261721441625, 41: 0.23760667878900496, 98349: 0.20549140246562134, 98348: 0.20670384610943687, 131121: 0.2772752617557772, 98354: 0.269340715553817, 131122: 0.2431940444492746, 98356: 0.19943184983011195, 131123: 0.13342575201979548, 98358: 0.23026265016849742, 131126: 0.22368552578968412, 131127: 0.20290610690483746, 57: 0.28180143875832325, 65595: 0.28467385427599146, 131133: 0.26196259767625624, 65597: 0.20497143315128408, 65599: 0.25214084507042256, 32840: 0.2957834908466063, 73: 0.2016922227605088, 65610: 0.2718602885345482, 65613: 0.26096209912536444, 80: 0.20168995042812077, 65620: 0.2756740941498945, 84: 0.20577248014344993, 86: 0.27853497635051033, 88: 0.28277180179753275, 65627: 0.26489693848862844, 65628: 0.20416029924959514, 65629: 0.19294274874978445, 95: 0.2023602287884611, 131167: 0.29557349711889314, 65637: 0.26359419863064126, 65638: 0.25313198156160743, 102: 0.25214794782951633, 65642: 0.28589680118817573, 65643: 0.24493425823311304, 98412: 0.2914258737729737, 106: 0.2598069806254989, 131180: 0.25543633354260603, 98417: 0.2796488377905524, 114: 0.28049009776886435, 117: 0.2574086588925475, 119: 0.2148351714289143, 120: 0.1872457037664606, 65657: 0.22618385808864405, 124: 0.21924753833341498, 98431: 0.2625080649891489, 98432: 0.23953329676064064, 131204: 0.2660108769948587, 98439: 0.2844341346383006, 131209: 0.25741976302772346, 98441: 0.2106439808441291, 131211: 0.1943419167137088, 65676: 0.27169112625396485, 131212: 0.23058593196542884, 131215: 0.22449900930500866, 98449: 0.2460316369583442, 131217: 0.22332555731590176, 131221: 0.2934513564461929, 131222: 0.24514892160219104, 98456: 0.24579180053271824, 155: 0.2861207006776627, 157: 0.21223725236813715, 98463: 0.2158037490205533, 131234: 0.3040576116310274, 164: 0.2781238833563783, 131237: 0.23263852791350453, 98471: 0.2811243718592965, 172: 0.2393955603102434, 98477: 0.21298466443791417, 65713: 0.2882676886412676, 178: 0.2754577627327281, 179: 0.22038113058893047, 65718: 0.2542969970737805, 65719: 0.25236833201759334, 184: 0.23497447071022615, 65723: 0.26570292092139636, 189: 0.23673005210124037, 131263: 0.28059561128526644, 131266: 0.24856984171063592, 131272: 0.2879246011322697, 131273: 0.23252370437719183, 98506: 0.30462674630319736, 131279: 0.27662829328594607, 98511: 0.26352435487907205, 98512: 0.24480028442888593, 131281: 0.21358945296188034, 65751: 0.2860384111462627, 65753: 0.2740829199583563, 131292: 0.27700068081945906, 98529: 0.26153396639883125, 65763: 0.2834343978087744, 98532: 0.2131926498433983, 229: 0.3106152618246174, 131302: 0.24759006984302606, 131303: 0.2448505074267582, 98536: 0.2530675713881821, 231: 0.19758073416771516, 98540: 0.22011557850731586, 131309: 0.2662363736410821, 98541: 0.19294274874978445, 98545: 0.2471969069317868, 242: 0.2235626155152605, 131315: 0.304699334502068, 131320: 0.293359989512323, 131322: 0.22599540485267755, 131323: 0.14116403952151527, 131324: 0.21851960353498365, 131326: 0.23016199537156082, 131329: 0.25550195529928926, 65794: 0.260567070330694, 13133 ...

# %% [markdown]
# # Degree assortativity of a network

# %% [markdown]
# Assortativity can be measured in different ways. A simple approach is measuring the average nearest neighbor degree to assess the level of degree-assortativity.

# %%
from collections import defaultdict

# %%
x=[]
y=[]

avg_knn=defaultdict(list)

for n in G.nodes():
    k=G.degree(n)
    
    #nn=len(G.neighbors(n))
    total=0
    for j in G.neighbors(n):
        total+=G.degree(j)
    
    avg_knn[k].append(float(total)/k)
    
    x.append(k)
    y.append(float(total)/k)

# %%
plt.figure(figsize=(10,7))
plt.scatter(x,y)

plt.xlabel('$k_i$', fontsize=18)
plt.ylabel('$k_{nn}$', fontsize=18)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.yscale('log')
plt.xscale('log')
plt.axis([0.1,1000,1,1000])
plt.show()

# %%
z=[]
for k in sorted(avg_knn.keys()):
    knn=np.array(avg_knn[k])
    z.append(np.average(knn))

# %%
plt.figure(figsize=(10,7))
plt.scatter(x,y)
plt.plot(sorted(avg_knn.keys()), z,'-r')

plt.xlabel('$k_i$', fontsize=18)
plt.ylabel('$k_{nn}$', fontsize=18)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.yscale('log')
plt.xscale('log')
plt.axis([0.1,1000,1,1000])
plt.show()

# %%
r=nx.degree_assortativity_coefficient(G)

# %%
print(r)
# Out:
# 0.20512067898648875

# %% [markdown]
# The degree assortativity coefficient of a ER graph is zero. The ER graph has no correlations.

# %%
ERr=nx.degree_assortativity_coefficient(ER)

# %%
ERr
# Out:
# 0.0021511342820397196

# %% [markdown]
# NetworkX offers a number of functions to compute the same quantity.

# %%
knn_avg2=nx.average_degree_connectivity(G)

# %%
print(knn_avg2)
# Out:
# {75: 77.99882352941177, 31: 58.04037897586284, 43: 69.43556771545828, 2: 23.927865037812683, 90: 77.11203703703704, 42: 60.331389698736636, 118: 78.43502824858757, 30: 57.107625272331155, 113: 80.56814159292036, 3: 28.27523510971787, 28: 58.709793351302785, 8: 39.26327433628319, 158: 86.37341772151899, 13: 44.994888023369036, 77: 73.6357733175915, 36: 62.516007532956685, 257: 86.91439688715953, 12: 42.094705443698736, 134: 89.48258706467662, 55: 78.45880077369439, 171: 82.84210526315789, 86: 81.7296511627907, 15: 48.993356242840775, 274: 96.15328467153284, 47: 67.27006769825918, 91: 80.11648351648351, 22: 49.707849419303166, 150: 90.85555555555555, 14: 44.20594010800196, 6: 35.63912864775997, 52: 71.10063224446786, 67: 75.60914179104478, 108: 87.86516203703704, 27: 60.657407407407405, 142: 87.4906103286385, 62: 64.69180470793374, 7: 37.66788247213779, 61: 76.44262295081967, 49: 68.4408811143505, 132: 81.35950413223141, 41: 67.15829746532759, 5: 33.02613981762918, 32: 61.44760338345865, 20: 46.04779411764706, 50: 65.12612903225806, 56: 74.32245879120879, 18: 50.58738425925926, 44: 67.23400673400674, 81: 81.11552028218695, 9: 39.82104805392477, 84: 76.93650793650794, 123: 86.35040650406503, 120: 94.29166666666667, 82: 70.11293743372217, 59: 80.08916728076639, 10: 40.97029288702929, 109: 80.96238532110091, 21: 52.61680378957866, 72: 76.99714052287581, 33: 62.90030303030303, 103: 76.49393203883496, 93: 81.32453567937439, 19: 47.950607287449394, 60: 74.33186274509804, 48: 63.18070652173913, 222: 101.52477477477477, 40: 62.843686868686866, 154: 103.51298701298701, 66: 70.86293164200141, 220: 106.10909090909091, 24: 50.449945887445885, 152: 91.66973684210527, 323: 97.31424148606811, 115: 81.92028985507247, 34: 62.29171668667467, 271: 96.6309963099631, 53: 73.98842767295598, 4: 28.074249605055293, 336: 98.73214285714286, 297: 89.98653198653199, 1: 26.308352849336455, 89: 69.29775280898876, 25: 54.5074358974359, 175: 98.65904761904761, 162: 88.1358024691358, 16: 46.23848684210526, 99: 72.37373737373737, 46: 69.40893719806763, 73: 73.25939019001326, 68: 76.09684361549498, 39: 64.08641975308642, 292: 91.95547945205479, 138: 73.68478260869566, 26: 55.29113601630158, 63: 79.52910052910053, 169: 93.17455621301775, 333: 105.03603603603604, 143: 82.3076923076923, 100: 79.43166666666667, 29: 53.666815942678014, 11: 43.09002861545235, 88: 74.02093301435407, 128: 73.29427083333333, 178: 74.9119850187266, 57: 81.13241436925648, 156: 97.37606837606837, 76: 87.00952813067151, 105: 84.74502164502165, 58: 76.20862068965518, 136: 75.375, 104: 76.21016483516483, 85: 68.66252100840336, 97: 79.32371134020619, 45: 64.81346153846154, 111: 84.53153153153153, 38: 68.21468144044321, 185: 84.52162162162162, 362: 67.93646408839778, 174: 101.43218390804597, 17: 47.41758682995383, 51: 62.1376858435682, 121: 105.99380165289256, 117: 93.53525641025641, 54: 69.85, 74: 72.97406866325785, 65: 70.1940170940171, 80: 83.67164634146341, 112: 88.08516483516483, 369: 90.9810298102981, 188: 96.26595744680851, 166: 87.96626506024096, 64: 81.19609375, 71: 71.77288732394366, 427: 80.43091334894613, 98: 79.70222634508349, 420: 94.3, 213: 94.11854460093896, 163: 93.4877300613497, 107: 83.84687275341481, 102: 90.34531590413944, 173: 93.39306358381504, 139: 81.76169064748201, 95: 77.54331983805668, 23: 50.715701734624915, 70: 73.13809523809523, 281: 77.79715302491103, 504: 85.43253968253968, 126: 87.87301587301587, 149: 85.1241610738255, 140: 93.74642857142857, 153: 79.52178649237473, 96: 75.64518229166667, 133: 95.18233082706767, 83: 86.41949616648412, 35: 60.71684088269454, 155: 81.51935483870967, 144: 99.8013888888889, 92: 86.64208074534162, 122: 81.81762295081967, 229: 93.7292576419214, 87: 76.35249042145594, 151: 72.03311258278146, 125: 88.24177777777778, 141: 96.60141843971631, 235: 99.10212765957446, 135: 86.92407407407407, 69: 73.65309898242369, 37: 64.36090636090636, 129: 83.13510520487264, 110: 85.44415584415584, 79: 79.24367088607595, 78: 79.1693657219973, 119: 63.448979 ...

# %%
knn_avg3=nx.k_nearest_neighbors(G)

# %%
print(knn_avg3)
# Out:
# {75: 77.99882352941177, 31: 58.04037897586284, 43: 69.43556771545828, 2: 23.927865037812683, 90: 77.11203703703704, 42: 60.331389698736636, 118: 78.43502824858757, 30: 57.107625272331155, 113: 80.56814159292036, 3: 28.27523510971787, 28: 58.709793351302785, 8: 39.26327433628319, 158: 86.37341772151899, 13: 44.994888023369036, 77: 73.6357733175915, 36: 62.516007532956685, 257: 86.91439688715953, 12: 42.094705443698736, 134: 89.48258706467662, 55: 78.45880077369439, 171: 82.84210526315789, 86: 81.7296511627907, 15: 48.993356242840775, 274: 96.15328467153284, 47: 67.27006769825918, 91: 80.11648351648351, 22: 49.707849419303166, 150: 90.85555555555555, 14: 44.20594010800196, 6: 35.63912864775997, 52: 71.10063224446786, 67: 75.60914179104478, 108: 87.86516203703704, 27: 60.657407407407405, 142: 87.4906103286385, 62: 64.69180470793374, 7: 37.66788247213779, 61: 76.44262295081967, 49: 68.4408811143505, 132: 81.35950413223141, 41: 67.15829746532759, 5: 33.02613981762918, 32: 61.44760338345865, 20: 46.04779411764706, 50: 65.12612903225806, 56: 74.32245879120879, 18: 50.58738425925926, 44: 67.23400673400674, 81: 81.11552028218695, 9: 39.82104805392477, 84: 76.93650793650794, 123: 86.35040650406503, 120: 94.29166666666667, 82: 70.11293743372217, 59: 80.08916728076639, 10: 40.97029288702929, 109: 80.96238532110091, 21: 52.61680378957866, 72: 76.99714052287581, 33: 62.90030303030303, 103: 76.49393203883496, 93: 81.32453567937439, 19: 47.950607287449394, 60: 74.33186274509804, 48: 63.18070652173913, 222: 101.52477477477477, 40: 62.843686868686866, 154: 103.51298701298701, 66: 70.86293164200141, 220: 106.10909090909091, 24: 50.449945887445885, 152: 91.66973684210527, 323: 97.31424148606811, 115: 81.92028985507247, 34: 62.29171668667467, 271: 96.6309963099631, 53: 73.98842767295598, 4: 28.074249605055293, 336: 98.73214285714286, 297: 89.98653198653199, 1: 26.308352849336455, 89: 69.29775280898876, 25: 54.5074358974359, 175: 98.65904761904761, 162: 88.1358024691358, 16: 46.23848684210526, 99: 72.37373737373737, 46: 69.40893719806763, 73: 73.25939019001326, 68: 76.09684361549498, 39: 64.08641975308642, 292: 91.95547945205479, 138: 73.68478260869566, 26: 55.29113601630158, 63: 79.52910052910053, 169: 93.17455621301775, 333: 105.03603603603604, 143: 82.3076923076923, 100: 79.43166666666667, 29: 53.666815942678014, 11: 43.09002861545235, 88: 74.02093301435407, 128: 73.29427083333333, 178: 74.9119850187266, 57: 81.13241436925648, 156: 97.37606837606837, 76: 87.00952813067151, 105: 84.74502164502165, 58: 76.20862068965518, 136: 75.375, 104: 76.21016483516483, 85: 68.66252100840336, 97: 79.32371134020619, 45: 64.81346153846154, 111: 84.53153153153153, 38: 68.21468144044321, 185: 84.52162162162162, 362: 67.93646408839778, 174: 101.43218390804597, 17: 47.41758682995383, 51: 62.1376858435682, 121: 105.99380165289256, 117: 93.53525641025641, 54: 69.85, 74: 72.97406866325785, 65: 70.1940170940171, 80: 83.67164634146341, 112: 88.08516483516483, 369: 90.9810298102981, 188: 96.26595744680851, 166: 87.96626506024096, 64: 81.19609375, 71: 71.77288732394366, 427: 80.43091334894613, 98: 79.70222634508349, 420: 94.3, 213: 94.11854460093896, 163: 93.4877300613497, 107: 83.84687275341481, 102: 90.34531590413944, 173: 93.39306358381504, 139: 81.76169064748201, 95: 77.54331983805668, 23: 50.715701734624915, 70: 73.13809523809523, 281: 77.79715302491103, 504: 85.43253968253968, 126: 87.87301587301587, 149: 85.1241610738255, 140: 93.74642857142857, 153: 79.52178649237473, 96: 75.64518229166667, 133: 95.18233082706767, 83: 86.41949616648412, 35: 60.71684088269454, 155: 81.51935483870967, 144: 99.8013888888889, 92: 86.64208074534162, 122: 81.81762295081967, 229: 93.7292576419214, 87: 76.35249042145594, 151: 72.03311258278146, 125: 88.24177777777778, 141: 96.60141843971631, 235: 99.10212765957446, 135: 86.92407407407407, 69: 73.65309898242369, 37: 64.36090636090636, 129: 83.13510520487264, 110: 85.44415584415584, 79: 79.24367088607595, 78: 79.1693657219973, 119: 63.448979 ...

# %%
r2=nx.degree_pearson_correlation_coefficient(G)
print(r2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-bcb10c49f038> in <module>()
# ----> 1 r2=nx.degree_pearson_correlation_coefficient(G)
#       2 print(r2)
#
# NameError: name 'nx' is not defined

# %% [markdown]
# ---
# # Simulating random and targeted attacks to a network

# %% [markdown]
# Resilience is the ability to provide and maintain an acceptable level of service in the face of faults and challenges to normal operation. Threats and challenges for services can range from simple misconfiguration over large scale natural disasters to targeted attacks.

# %% [markdown]
# We define a function that performs a random or targeted attack to a network according to a given strategy (random, degree based, betweenness based, etc. )

# %%
def net_attack(graph, ranked_nodes):
    
    fraction_removed=[]#here we store the tuples: (%removed nodes, size of gcc)
    
    graph1=graph.copy()
    nnodes=len(ranked_nodes)
    n=0    
    
    gcc=list(nx.connected_components(graph1))[0]
    
    gcc_size=float(len(gcc))/nnodes
    
    fraction_removed.append( (float(n)/nnodes, gcc_size) )
    
    while gcc_size>0.01:
        
        #we start from the end of the list!
        graph1.remove_node(ranked_nodes.pop())

        gcc=list(nx.connected_components(graph1))[0]
        gcc_size=float(len(gcc))/nnodes
        n+=1
        fraction_removed.append( (float(n)/nnodes, gcc_size) )
    
    return fraction_removed

# %% [markdown]
# # Robustness of the US airport network
# ## Random attack

# %%
filepath_air='./../network_data/USairport_2010.txt'

# %%
G=nx.Graph()
fh=open(filepath_air,'r')
for line in fh.readlines():
    s=line.strip().split()
    G.add_edge(int(s[0]),int(s[1]))
fh.close()

# %%
airport_nodes=list(G.nodes())

# %%
resilience_random=net_attack(G, airport_nodes)

# %% [markdown]
# ## Betweenness based attack

# %%
from operator import itemgetter

# %%
airport_nodes_betw=[]

betw=nx.betweenness_centrality(G)
for i in sorted(betw.items(), key=itemgetter(1)):
    airport_nodes_betw.append(i[0])


resilience_betw=net_attack(G, airport_nodes_betw)

# %% [markdown]
# ## Degree based attack

# %%
airport_nodes_degree=[]

deg=dict(G.degree())
for i in sorted(deg.items(), key=itemgetter(1)):
    airport_nodes_degree.append(i[0])


resilience_deg=net_attack(G, list(airport_nodes_degree))

# %% [markdown]
# Let's compare the results.

# %%
x=[k[0] for k in resilience_random]
y=[k[1] for k in resilience_random]

x1=[k[0] for k in resilience_deg]
y1=[k[1] for k in resilience_deg]

x2=[k[0] for k in resilience_betw]
y2=[k[1] for k in resilience_betw]

plt.figure(figsize=(10,7))

plt.plot(x,y, label='random attack')
plt.plot(x1,y1, label='degree based')
plt.plot(x2,y2, label='betw based')

plt.xlabel('$f_{c}$', fontsize=18)
plt.ylabel('$LCC$', fontsize=18)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

plt.legend(loc='upper right')

# %% [markdown]
# # Robustness of the Erdos-Renyi random network

# %%
ER=nx.fast_gnp_random_graph(2000,0.012)

# %%
ER_nodes=list(ER.nodes())

ER_nodes_deg=[i for i,d in sorted(dict(ER.degree()).items(), key=itemgetter(1))]

ER_betw=nx.betweenness_centrality(ER)
ER_nodes_betw=[i for i,b in sorted(dict(ER.ER_betw()).items(), key=itemgetter(1))

# %%
resilience_random=net_attack(ER, ER_nodes)
resilience_deg=net_attack(ER, ER_nodes_deg)
resilience_betw=net_attack(ER, ER_nodes_betw)

# %%
x=[k[0] for k in resilience_random]
y=[k[1] for k in resilience_random]

x1=[k[0] for k in resilience_deg]
y1=[k[1] for k in resilience_deg]

x2=[k[0] for k in resilience_betw]
y2=[k[1] for k in resilience_betw]

plt.figure(figsize=(10,7))

plt.plot(x,y, label='random attack')
plt.plot(x1,y1, label='degree based')
plt.plot(x2,y2, label='betw based')

plt.xlabel('$f_{c}$', fontsize=18)
plt.ylabel('$LCC$', fontsize=18)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

plt.legend(loc='upper right')
